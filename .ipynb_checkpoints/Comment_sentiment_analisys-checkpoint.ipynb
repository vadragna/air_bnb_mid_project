# %%
# !pip install langdetect

# %%
# !pip install vaderSentiment

# %%
# !pip install transformers

# %%
# !pip install wordcloud matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from langdetect import detect
import getpass
from sqlalchemy import create_engine
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from collections import Counter
from wordcloud import WordCloud

# %%
password = getpass.getpass()
# Out:
#  ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/air_bnb_reviews'
engine = create_engine(connection_string)

# %%
query = 'SELECT * FROM air_bnb_berlin'

# %%
df = pd.read_sql_query(query, engine)
df.head(30)
# Out:
#     index  review_id review_date  reviewer_id reviewer_name  \
# 0       0   58660447  2016-01-03     14876562        Dennis
# 1       2   58663795  2016-01-03     49367757       Andreea
# 2       3   59003619  2016-01-05     46694292         Sasha
# 3       4   66845661  2016-03-25     54542819        Yohana
# 4       5   67969785  2016-04-01     35352843      Mitchell
# 5       6   68816282  2016-04-06     48006291         Cindy
# 6       7   69289363  2016-04-10     63759402         Marco
# 7       8   69780867  2016-04-13     53960263      Santiago
# 8       9   70426866  2016-04-17     26184931       Eduardo
# 9      10   78320875  2016-06-06     12388715          Luke
# 10     11   79774492  2016-06-14     68962851           Cem
# 11     12   95862871  2016-08-21     46516760           Tea
# 12     13   97218563  2016-08-26     39674640         David
# 13     14   97873838  2016-08-28     87508199     Andrea A.
# 14     15   99116865  2016-09-03     24571916           Dan
# 15     16   99146485  2016-09-03     19768857        Miriam
# 16     17  105839794  2016-10-03     79610460        Carmen
# 17     18  106609055  2016-10-07     68871505        Tobias
# 18     19  129351385  2017-01-30    112696691         Iulia
# 19     20  130028369  2017-02-04    110520084        Germán
# 20     21  131452294  2017-02-12     57829933       Antonio
# 21     22   57714402  2015-12-28     51441825         Emily
# 22     23   59081613  2016-01-06     50827784          Zita
# 23     24   58207335  2016-01-01     19836055        Camila
# 24     25   66204356  2016-03-20     13816657     Francesca
# 25     26   67531824  2016-03-30     59756374         Llama
# 26     27   58982127  2016-01-05     24321597        Pavlos
# 27     29   58658086  2016-01-03      9996400       Mathieu
# 28     30   65440054  2016-03-13     32308915        German
# 29     31   65451319  2016-03-13     31732596       Mathias
#
#                                              comments  listing_id  \
# 0   Very nice, clean appartement! Josh was really ...    10002699
# 1   Aki is really nice and friendly. We had an ama...    10006647
# 2   Aki is a very nice dude with a clean place in ...    10006647
# 3   Aki's place was easy to find and located in th...    10006647
# 4   We had to wait 30mins for Aki to arrive but ot...    10006647
# 5   Great room, very comfortable and clean. Aki an...    10006647
# 6   Aki was really friendly and available giving u...    10006647
# 7   Aki es sin duda el mejor host q uno puede tene...    10006647
# 8   We did not meer Aki, but we did meet Fabián, h...    10006647
# 9   Aki was an awesome host in Berlin. We got alon...    10006647
# 10  Aki was a good host. We didn't see him much bu...    10006647
# 11  The apartment for me was very different from w...    10006647
# 12  Great location. Safe neighborhood. Simple room...    10006647
# 13  Aki per me è stato molto piùdi host..è stato u...    10006647
# 14  The host canceled this reservation 5 days befo...    10006647
# 15  Es war eine typische Studentenwohnung in tolle...    10006647
# 16  We stayed in Aki' s place for 2 nights. Aki wa...    10006647
# 17  Super entspannter Gastgeber. War sehr angenehm...    10006647
# 18  Great area, a few minutes away from Alexanderp...    10006647
# 19  Excelente ubicación y es muy cómodo, Aki es mu...    10006647
# 20  Aki is a really nice person. Perfect comunicat...    10006647
# 21  We stayed at Esther's apartment over Christmas...    10006747
# 22  The apartment was big, easy to find and very c...    10006747
# 23  Really cool place to stay, we couldn't meet Ki...    10007526
# 24  I didn't actually meet Kian but he left lovely...    10007526
# 25  Una estancia apacible y tranquila muy cerca de...    10007526
# 26  This apartment is beautiful and warm. Filled w...    10007952
# 27  Very nice, clean and quiet apartment with ever...    10008354
# 28  Caroline was really nice and open to help with...    10008354
# 29  Super Unterkunft. Organisatorisch alles besten...    10008354
#
#                               listing_url  \
# 0   https://www.airbnb.com/rooms/10002699
# 1   https://www.airbnb.com/rooms/10006647
# 2   https://www.airbnb.com/rooms/10006647
# 3   https://www.airbnb.com/rooms/10006647
# 4   https://www.airbnb.com/rooms/10006647
# 5   https://www.airbnb.com/rooms/10006647
# 6   https://www.airbnb.com/rooms/10006647
# 7   https://www.airbnb.com/rooms/10006647
# 8   https://www.airbnb.com/rooms/10006647
# 9   https://www.airbnb.com/rooms/10006647
# 10  https://www.airbnb.com/rooms/10006647
# 11  https://www.airbnb.com/rooms/10006647
# 12  https://www.airbnb.com/rooms/10006647
# 13  https://www.airbnb.com/rooms/10006647
# 14  https://www.airbnb.com/rooms/10006647
# 15  https://www.airbnb.com/rooms/10006647
# 16  https://www.airbnb.com/rooms/10006647
# 17  https://www.airbnb.com/rooms/10006647
# 18  https://www.airbnb.com/rooms/10006647
# 19  https://www.airbnb.com/rooms/10006647
# 20  https://www.airbnb.com/rooms/10006647
# 21  https://www.airbnb.com/rooms/10006747
# 22  https://www.airbnb.com/rooms/10006747
# 23  https://www.airbnb.com/rooms/10007526
# 24  https://www.airbnb.com/rooms/10007526
# 25  https://www.airbnb.com/rooms/10007526
# 26  https://www.airbnb.com/rooms/10007952
# 27  https://www.airbnb.com/rooms/10008354
# 28  https://www.airbnb.com/rooms/10008354
# 29  https://www.airbnb.com/rooms/10008354
#
#                            listing_name   host_id  ... last_review  \
# 0       Trendy and peaceful KreuzkÃ¶lln  44696672  ...  2016-01-03
# 1           Very central and very quite  40791092  ...  2017-02-12
# 2           Very central and very quite  40791092  ...  2017-02-12
# 3           Very central and very quite  40791092  ...  2017-02-12
# 4           Very central and very quite  40791092  ...  2017-02-12
# 5           Very central and very quite  40791092  ...  2017-02-12
# 6           Very central and very quite  40791092  ...  2017-02-12
# 7           Very central and very quite  40791092  ...  2017-02-12
# 8           Very central and very quite  40791092  ...  2017-02-12
# 9           Very central and very quite  40791092  ...  2017-02-12
# 10          Very central and very quite  40791092  ...  2017-02-12
# 11          Very central and very quite  40791092  ...  2017-02-12
# 12          Very central and very quite  40791092  ...  2017-02-12
# 13          Very central and very quite  40791092  ...  2017-02-12
# 14          Very central and very quite  40791092  ...  2017-02-12
# 15          Very central and very quite  40791092  ...  2017-02-12
# 16          Very central and very quite  40791092  ...  2017-02-12
# 17          Very central and very quite  40791092  ...  2017-02-12
# 18          Very central and very quite  40791092  ...  2017-02-12
# 19          Very central and very quite  40791092  ...  2017-02-12
# 20          Very central and very quite  40791092  ...  2017-02-12
# 21       Altbauwohnung in Berlin-Pankow  51401040  ...  2016-01-06
# 22       Altbauwohnung in Berlin-Pankow  51401040  ...  2016-01-06
# 23    Mauerblick: Kreuzberg meets Mitte   8344366  ...  2016-03-30
# 24    Mauerblick: Kreuzberg meets Mitte   8344366  ...  2016-03-30
# 25    Mauerblick: Kreuzberg meets Mitte   8344366  ...  2016-03-30
# 26  Private room in exclusive apartment   2305159  ...  2016-01-05
# 27             Cosy studio in Weserstr.  26193350  ...  2018-01-24
# 28             Cosy studio in Weserstr.  26193350  ...  2018-01-24
# 29             Cosy studio in Weserstr.  26193350  ...  2018-01-24
#
#    overall_rating accuracy_rating cleanliness_rating checkin_rating  \
# 0             100               8                 10              6
# 1              92               9                  8              9
# 2              92               9                  8              9
# 3              92               9                  8              9
# 4              92               9                  8              9
# 5              92               9                  8              9
# 6              92               9                  8              9
# 7              92               9                  8              9
# 8              92               9                  8              9
# 9              92               9                  8              9
# 10             92               9                  8              9
# 11             92               9                  8              9
# 12             92               9                  8              9
# 13             92               9                  8              9
# 14             92               9                  8              9
# 15             92               9                  8              9
# 16             92               9                  8              9
# 17             92               9                  8              9
# 18             92               9                  8              9
# 19             92               9                  8              9
# 20             92               9                  8              9
# 21             90              10                  9              9
# 22             90              10                  9              9
# 23            100              10                  9             10
# 24            100              10                  9             10
# 25            100              10                  9             10
# 26            100              10                 10             10
# 27             91               9                  9             10
# 28             91               9                  9             10
# 29             91               9                  9             10
#
#    communication_rating location_rating value_rating instant_bookable  \
# 0                    10              10           10                f
# 1                    10              10            9                f
# 2                    10              10            9                f
# 3                    10              10            9                f
# 4                    10              10            9                f
# 5                    10              10            9                f
# 6                    10              10            9                f
# 7                    10              10            9                f
# 8                    10              10            9                f
# 9                    10              10            9                f
# 10                   10              10            9                f
# 11                   10              10            9                f
# 12                   10              10            9                f
# 13                   10              10            9                f
# 14                   10              10            9                f
# 15                   10              10            9                f
# 16                   10              10            9                f
# 17                   10              10            9                f
# 18                   10              10            9                f
# 19                   10              10            9                f
# 20                   10              10            9                f
# 21                    8               9            9                f
# 22                    8               9            9                f
# 23                   10               9            9                t
# 24                   10               9            9                t
# 25                   10               9            9                t
# 26                   10              10           10                f
# 27                   10               9            9                t
# 28                   10               9            9                t
# 29                   10               9            9                t
#
#    business_travel_ready
# 0                      f
# 1                      f
# 2                      f
# 3                      f
# 4                      f
# 5                      f
# 6                      f
# 7                      f
# 8                      f
# 9                      f
# 10                     f
# 11                     f
# 12                     f
# 13                     f
# 14                     f
# 15                     f
# 16                     f
# 17                     f
# 18                     f
# 19                     f
# 20                     f
# 21                     f
# 22                     f
# 23                     f
# 24                     f
# 25                     f
# 26                     f
# 27                     f
# 28                     f
# 29                     f
#
# [30 rows x 47 columns]

# %% [markdown]
# Using langdetect I am going to count the comments rows based on their language. Before that for performances reasons (I cannot use the whole df), I am going to select all the reviews that belong to the top 2000 rated properties and the 2000 least rated properties. I am going to analyse if we can spot some differences.

# %%
df_os_sorted = df.sort_values(by='overall_rating', ascending=False)
top_500_unique_listing_ids = df_os_sorted['listing_id'].unique()[:2000]
best_rated = df[df['listing_id'].isin(top_500_unique_listing_ids)]

# %%
best_rated.head()
# Out:
#        index  review_id review_date  reviewer_id reviewer_name  \
# 0          0   58660447  2016-01-03     14876562        Dennis
# 19556  19730   74177909  2016-05-13     49290567      Johannes
# 19557  19731  428556530  2019-03-25    229218552       Florian
# 19622  19796   64944440  2016-03-09     49407647         Tugce
# 19775  19951   65638467  2016-03-16     34740943      Angeline
#
#                                                 comments  listing_id  \
# 0      Very nice, clean appartement! Josh was really ...    10002699
# 19556  Trotz deutlicher Verspà¤tung bei der Anreise w...    11328533
# 19557  Alles in allem ein wirklich schà¶nes Domizil m...    11328533
# 19622  Alexandra's apartment is comfortable and she w...    11337277
# 19775  Accueil chaleureux dans une chambre très grand...    11348934
#
#                                  listing_url  \
# 0      https://www.airbnb.com/rooms/10002699
# 19556  https://www.airbnb.com/rooms/11328533
# 19557  https://www.airbnb.com/rooms/11328533
# 19622  https://www.airbnb.com/rooms/11337277
# 19775  https://www.airbnb.com/rooms/11348934
#
#                                listing_name   host_id  ... last_review  \
# 0           Trendy and peaceful KreuzkÃ¶lln  44696672  ...  2016-01-03
# 19556    Charming tiny house close to lakes  59278295  ...  2019-03-25
# 19557    Charming tiny house close to lakes  59278295  ...  2019-03-25
# 19622  GemÃ¼tliches Zimmer in WG zu vegeben  48503637  ...  2016-03-09
# 19775      GroÃes Zimmer im Herzen Berlins  59430981  ...  2017-11-23
#
#       overall_rating accuracy_rating cleanliness_rating checkin_rating  \
# 0                100               8                 10              6
# 19556            100              10                 10             10
# 19557            100              10                 10             10
# 19622            100              10                 10             10
# 19775            100              10                  9              9
#
#       communication_rating location_rating value_rating instant_bookable  \
# 0                       10              10           10                f
# 19556                   10               9            8                f
# 19557                   10               9            8                f
# 19622                   10              10           10                f
# 19775                    9              10           10                t
#
#       business_travel_ready
# 0                         f
# 19556                     f
# 19557                     f
# 19622                     f
# 19775                     f
#
# [5 rows x 47 columns]

# %%
best_rated.shape
# Out:
# (8075, 47)

# %%
df_os_sorted = df.sort_values(by='overall_rating', ascending=True)
top_500_unique_listing_ids = df_os_sorted['listing_id'].unique()[:2000]
least_rated = df[df['listing_id'].isin(top_500_unique_listing_ids)]

# %%
least_rated.head()
# Out:
#      index  review_id review_date  reviewer_id reviewer_name  \
# 44      46   61420583  2016-02-04     15950634       Richard
# 45      47   63012333  2016-02-19     21927977        Markus
# 46      48   71527986  2016-04-26     64264440      Vladimir
# 70      72   57860388  2015-12-29     28831125     Gian Luca
# 607    615   61387388  2016-02-03      4443910          Jean
#
#                                               comments  listing_id  \
# 44   The host canceled this reservation the day bef...    10008709
# 45   Nice place, room is small but clean, flat is i...    10008709
# 46   The host canceled this reservation 11 days bef...    10008709
# 70   The host canceled this reservation the day bef...    10015667
# 607  Oui, super appart', super Margo, super quartie...    10037904
#
#                                listing_url  \
# 44   https://www.airbnb.com/rooms/10008709
# 45   https://www.airbnb.com/rooms/10008709
# 46   https://www.airbnb.com/rooms/10008709
# 70   https://www.airbnb.com/rooms/10015667
# 607  https://www.airbnb.com/rooms/10037904
#
#                            listing_name   host_id  ... last_review  \
# 44          Cozy room in Friedrichshain  47456791  ...  2016-04-26
# 45          Cozy room in Friedrichshain  47456791  ...  2016-04-26
# 46          Cozy room in Friedrichshain  47456791  ...  2016-04-26
# 70   SchÃ¶ner Altbau in cooler Kiezlage  14847265  ...  2015-12-29
# 607     helle, ruhige Maisonettewohnung  10464825  ...  2018-01-01
#
#     overall_rating accuracy_rating cleanliness_rating checkin_rating  \
# 44              80               8                  6             10
# 45              80               8                  6             10
# 46              80               8                  6             10
# 70               0               0                  0              0
# 607             75               9                  9              9
#
#     communication_rating location_rating value_rating instant_bookable  \
# 44                    10              10            6                f
# 45                    10              10            6                f
# 46                    10              10            6                f
# 70                     0               0            0                f
# 607                    8              10            9                f
#
#     business_travel_ready
# 44                      f
# 45                      f
# 46                      f
# 70                      f
# 607                     f
#
# [5 rows x 47 columns]

# %%
least_rated.shape
# Out:
# (11478, 47)

# %%
best_rated.head()
# Out:
#        index  review_id review_date  reviewer_id reviewer_name  \
# 0          0   58660447  2016-01-03     14876562        Dennis
# 19556  19730   74177909  2016-05-13     49290567      Johannes
# 19557  19731  428556530  2019-03-25    229218552       Florian
# 19622  19796   64944440  2016-03-09     49407647         Tugce
# 19775  19951   65638467  2016-03-16     34740943      Angeline
#
#                                                 comments  listing_id  \
# 0      Very nice, clean appartement! Josh was really ...    10002699
# 19556  Trotz deutlicher Verspà¤tung bei der Anreise w...    11328533
# 19557  Alles in allem ein wirklich schà¶nes Domizil m...    11328533
# 19622  Alexandra's apartment is comfortable and she w...    11337277
# 19775  Accueil chaleureux dans une chambre très grand...    11348934
#
#                                  listing_url  \
# 0      https://www.airbnb.com/rooms/10002699
# 19556  https://www.airbnb.com/rooms/11328533
# 19557  https://www.airbnb.com/rooms/11328533
# 19622  https://www.airbnb.com/rooms/11337277
# 19775  https://www.airbnb.com/rooms/11348934
#
#                                listing_name   host_id  ... last_review  \
# 0           Trendy and peaceful KreuzkÃ¶lln  44696672  ...  2016-01-03
# 19556    Charming tiny house close to lakes  59278295  ...  2019-03-25
# 19557    Charming tiny house close to lakes  59278295  ...  2019-03-25
# 19622  GemÃ¼tliches Zimmer in WG zu vegeben  48503637  ...  2016-03-09
# 19775      GroÃes Zimmer im Herzen Berlins  59430981  ...  2017-11-23
#
#       overall_rating accuracy_rating cleanliness_rating checkin_rating  \
# 0                100               8                 10              6
# 19556            100              10                 10             10
# 19557            100              10                 10             10
# 19622            100              10                 10             10
# 19775            100              10                  9              9
#
#       communication_rating location_rating value_rating instant_bookable  \
# 0                       10              10           10                f
# 19556                   10               9            8                f
# 19557                   10               9            8                f
# 19622                   10              10           10                f
# 19775                    9              10           10                t
#
#       business_travel_ready
# 0                         f
# 19556                     f
# 19557                     f
# 19622                     f
# 19775                     f
#
# [5 rows x 47 columns]

# %%
least_rated.head()
# Out:
#      index  review_id review_date  reviewer_id reviewer_name  \
# 44      46   61420583  2016-02-04     15950634       Richard
# 45      47   63012333  2016-02-19     21927977        Markus
# 46      48   71527986  2016-04-26     64264440      Vladimir
# 70      72   57860388  2015-12-29     28831125     Gian Luca
# 607    615   61387388  2016-02-03      4443910          Jean
#
#                                               comments  listing_id  \
# 44   The host canceled this reservation the day bef...    10008709
# 45   Nice place, room is small but clean, flat is i...    10008709
# 46   The host canceled this reservation 11 days bef...    10008709
# 70   The host canceled this reservation the day bef...    10015667
# 607  Oui, super appart', super Margo, super quartie...    10037904
#
#                                listing_url  \
# 44   https://www.airbnb.com/rooms/10008709
# 45   https://www.airbnb.com/rooms/10008709
# 46   https://www.airbnb.com/rooms/10008709
# 70   https://www.airbnb.com/rooms/10015667
# 607  https://www.airbnb.com/rooms/10037904
#
#                            listing_name   host_id  ... last_review  \
# 44          Cozy room in Friedrichshain  47456791  ...  2016-04-26
# 45          Cozy room in Friedrichshain  47456791  ...  2016-04-26
# 46          Cozy room in Friedrichshain  47456791  ...  2016-04-26
# 70   SchÃ¶ner Altbau in cooler Kiezlage  14847265  ...  2015-12-29
# 607     helle, ruhige Maisonettewohnung  10464825  ...  2018-01-01
#
#     overall_rating accuracy_rating cleanliness_rating checkin_rating  \
# 44              80               8                  6             10
# 45              80               8                  6             10
# 46              80               8                  6             10
# 70               0               0                  0              0
# 607             75               9                  9              9
#
#     communication_rating location_rating value_rating instant_bookable  \
# 44                    10              10            6                f
# 45                    10              10            6                f
# 46                    10              10            6                f
# 70                     0               0            0                f
# 607                    8              10            9                f
#
#     business_travel_ready
# 44                      f
# 45                      f
# 46                      f
# 70                      f
# 607                     f
#
# [5 rows x 47 columns]

# %%
def detect_language(review):
    try:
        return detect(review)
    except:
        return "unknown"  

least_rated['language'] = least_rated['comments'].apply(detect_language)
best_rated['language'] = best_rated['comments'].apply(detect_language)
# Out:
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/1758036526.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   least_rated['language'] = least_rated['comments'].apply(detect_language)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/1758036526.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_rated['language'] = best_rated['comments'].apply(detect_language)

# %%
least_rated.head()
# Out:
#      index  review_id review_date  reviewer_id reviewer_name  \
# 44      46   61420583  2016-02-04     15950634       Richard
# 45      47   63012333  2016-02-19     21927977        Markus
# 46      48   71527986  2016-04-26     64264440      Vladimir
# 70      72   57860388  2015-12-29     28831125     Gian Luca
# 607    615   61387388  2016-02-03      4443910          Jean
#
#                                               comments  listing_id  \
# 44   The host canceled this reservation the day bef...    10008709
# 45   Nice place, room is small but clean, flat is i...    10008709
# 46   The host canceled this reservation 11 days bef...    10008709
# 70   The host canceled this reservation the day bef...    10015667
# 607  Oui, super appart', super Margo, super quartie...    10037904
#
#                                listing_url  \
# 44   https://www.airbnb.com/rooms/10008709
# 45   https://www.airbnb.com/rooms/10008709
# 46   https://www.airbnb.com/rooms/10008709
# 70   https://www.airbnb.com/rooms/10015667
# 607  https://www.airbnb.com/rooms/10037904
#
#                            listing_name   host_id  ... overall_rating  \
# 44          Cozy room in Friedrichshain  47456791  ...             80
# 45          Cozy room in Friedrichshain  47456791  ...             80
# 46          Cozy room in Friedrichshain  47456791  ...             80
# 70   SchÃ¶ner Altbau in cooler Kiezlage  14847265  ...              0
# 607     helle, ruhige Maisonettewohnung  10464825  ...             75
#
#     accuracy_rating cleanliness_rating checkin_rating communication_rating  \
# 44                8                  6             10                   10
# 45                8                  6             10                   10
# 46                8                  6             10                   10
# 70                0                  0              0                    0
# 607               9                  9              9                    8
#
#     location_rating value_rating instant_bookable business_travel_ready  \
# 44               10            6                f                     f
# 45               10            6                f                     f
# 46               10            6                f                     f
# 70                0            0                f                     f
# 607              10            9                f                     f
#
#     language
# 44        en
# 45        en
# 46        en
# 70        en
# 607       fr
#
# [5 rows x 48 columns]

# %%
best_rated.head()
# Out:
#        index  review_id review_date  reviewer_id reviewer_name  \
# 0          0   58660447  2016-01-03     14876562        Dennis
# 19556  19730   74177909  2016-05-13     49290567      Johannes
# 19557  19731  428556530  2019-03-25    229218552       Florian
# 19622  19796   64944440  2016-03-09     49407647         Tugce
# 19775  19951   65638467  2016-03-16     34740943      Angeline
#
#                                                 comments  listing_id  \
# 0      Very nice, clean appartement! Josh was really ...    10002699
# 19556  Trotz deutlicher Verspà¤tung bei der Anreise w...    11328533
# 19557  Alles in allem ein wirklich schà¶nes Domizil m...    11328533
# 19622  Alexandra's apartment is comfortable and she w...    11337277
# 19775  Accueil chaleureux dans une chambre très grand...    11348934
#
#                                  listing_url  \
# 0      https://www.airbnb.com/rooms/10002699
# 19556  https://www.airbnb.com/rooms/11328533
# 19557  https://www.airbnb.com/rooms/11328533
# 19622  https://www.airbnb.com/rooms/11337277
# 19775  https://www.airbnb.com/rooms/11348934
#
#                                listing_name   host_id  ... overall_rating  \
# 0           Trendy and peaceful KreuzkÃ¶lln  44696672  ...            100
# 19556    Charming tiny house close to lakes  59278295  ...            100
# 19557    Charming tiny house close to lakes  59278295  ...            100
# 19622  GemÃ¼tliches Zimmer in WG zu vegeben  48503637  ...            100
# 19775      GroÃes Zimmer im Herzen Berlins  59430981  ...            100
#
#       accuracy_rating cleanliness_rating checkin_rating communication_rating  \
# 0                   8                 10              6                   10
# 19556              10                 10             10                   10
# 19557              10                 10             10                   10
# 19622              10                 10             10                   10
# 19775              10                  9              9                    9
#
#       location_rating value_rating instant_bookable business_travel_ready  \
# 0                  10           10                f                     f
# 19556               9            8                f                     f
# 19557               9            8                f                     f
# 19622              10           10                f                     f
# 19775              10           10                t                     f
#
#       language
# 0           en
# 19556       de
# 19557       de
# 19622       en
# 19775       fr
#
# [5 rows x 48 columns]

# %% [markdown]
# I am going to eximine the distribution of the top and the least rated properties review languages

# %%
best_rated['language'].value_counts()
# Out:
# en         5504
# de         1774
# fr          263
# es          172
# pt           82
# it           64
# nl           32
# da           31
# vi           17
# af           17
# sv           17
# ro           16
# unknown      14
# pl           12
# no           11
# ca            9
# cs            7
# sq            6
# id            5
# cy            4
# zh-cn         4
# tl            3
# so            3
# hu            2
# sk            2
# sw            1
# fi            1
# et            1
# ko            1
# Name: language, dtype: int64

# %% [markdown]
# I am going to select one sample of random rows (10000) to compare the results with the ones I get using one variable.

# %%
sampled_df = df.sample(n=10000, random_state=42)

# %%
sampled_df['language'] = sampled_df['comments'].apply(detect_language)

# %% [markdown]
# To simplify, I will focus on the most spread European languages (English, German, Spanish, French, Italian) and group all other languages in "other"

# %%
def filter_in_main_languages(x):
    if x in ['en', 'fr', 'de', 'es', 'unknown']:
        return x
    else:
        return 'other'

# %%
best_rated['language'] = best_rated['language'].apply(filter_in_main_languages)
least_rated['language'] = least_rated['language'].apply(filter_in_main_languages)
# Out:
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/4071224411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_rated['language'] = best_rated['language'].apply(filter_in_main_languages)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/4071224411.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   least_rated['language'] = least_rated['language'].apply(filter_in_main_languages)

# %%
sampled_df['language'] = sampled_df['language'].apply(filter_in_main_languages)

# %%
best_rated_lang_perc = best_rated['language'].value_counts()/len(best_rated['language'])*100
best_rated_lang_perc
# Out:
# en         68.160991
# de         21.969040
# other       4.309598
# fr          3.256966
# es          2.130031
# unknown     0.173375
# Name: language, dtype: float64

# %%
least_rated_lang_perc = least_rated['language'].value_counts()/len(least_rated['language'])*100
least_rated_lang_perc
# Out:
# en         67.546611
# de         16.065517
# other       7.056979
# fr          5.201255
# es          3.807283
# unknown     0.322356
# Name: language, dtype: float64

# %%
sampled_df_lang_perc = sampled_df['language'].value_counts()/len(sampled_df['language'])*100

# %%
sampled_df_lang_perc
# Out:
# en         67.66
# de         18.91
# other       6.02
# fr          4.32
# es          2.87
# unknown     0.22
# Name: language, dtype: float64

# %%
combined_lang_perc = pd.concat([best_rated_lang_perc, sampled_df_lang_perc, least_rated_lang_perc], axis=1)
combined_lang_perc.columns = ['Best Rated', 'Sampled', 'Least Rated']


ax = combined_lang_perc.plot(kind='bar', figsize=(10, 6))
ax.set_ylabel('Percentage')
ax.set_title('Comparison of Language Distribution')
plt.xticks(rotation=0)  
plt.tight_layout()
plt.show()

# %% [markdown]
# The variation is not big but significant. We can observe that the percantage of other-than-English negative reviews increase for Franch, Spanish and Italian, decrease for German.

# %% [markdown]
# SENTIMENT ANALYSIS

# %% [markdown]
# For the sentiment analysis I am going to focus only to reviews that are in English

# %%
# Filter only English rows

# %%
best_rated_en = best_rated[best_rated['language'] == 'en']
least_rated_en = least_rated[least_rated['language'] == 'en']
sampled_df_en = sampled_df[sampled_df['language'] == 'en']

# %%
best_rated_en.shape
# Out:
# (5504, 48)

# %%
least_rated_en.shape
# Out:
# (7753, 48)

# %%
sampled_df_en.shape
# Out:
# (6766, 48)

# %%
analyzer = SentimentIntensityAnalyzer()

def get_sentiment_score(text):
    sentiment = analyzer.polarity_scores(text)
    return sentiment

# %%
def retrurn_pos(x):
    return x['pos']

def retrurn_neu(x):
    return x['neu']

def retrurn_neg(x):
    return x['neg']

# %%
def create_scores_columns(data_frame):
    data_frame['sentiment_scores'] = data_frame['comments'].apply(get_sentiment_score)
    data_frame['neg_score'] = data_frame['sentiment_scores'].apply(retrurn_neg)
    data_frame['pos_score'] = data_frame['sentiment_scores'].apply(retrurn_pos)
    data_frame['neu_score'] = data_frame['sentiment_scores'].apply(retrurn_neu)

# %%
create_scores_columns(best_rated_en)
create_scores_columns(least_rated_en)
create_scores_columns(sampled_df_en)
# Out:
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['sentiment_scores'] = data_frame['comments'].apply(get_sentiment_score)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['neg_score'] = data_frame['sentiment_scores'].apply(retrurn_neg)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['pos_score'] = data_frame['sentiment_scores'].apply(retrurn_pos)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['neu_score'] = data_frame['sentiment_scores'].apply(retrurn_neu)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['sentiment_scores'] = data_frame['comments'].apply(get_sentiment_score)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['neg_score'] = data_frame['sentiment_scores'].apply(retrurn_neg)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['pos_score'] = data_frame['sentiment_scores'].apply(retrurn_pos)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['neu_score'] = data_frame['sentiment_scores'].apply(retrurn_neu)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['sentiment_scores'] = data_frame['comments'].apply(get_sentiment_score)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['neg_score'] = data_frame['sentiment_scores'].apply(retrurn_neg)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['pos_score'] = data_frame['sentiment_scores'].apply(retrurn_pos)
# /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/ipykernel_45008/3091757554.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['neu_score'] = data_frame['sentiment_scores'].apply(retrurn_neu)

# %%
least_rated_en.head()
# Out:
#      index  review_id review_date  reviewer_id reviewer_name  \
# 44      46   61420583  2016-02-04     15950634       Richard
# 45      47   63012333  2016-02-19     21927977        Markus
# 46      48   71527986  2016-04-26     64264440      Vladimir
# 70      72   57860388  2015-12-29     28831125     Gian Luca
# 609    617   80843453  2016-06-20      9982744          Nina
#
#                                               comments  listing_id  \
# 44   The host canceled this reservation the day bef...    10008709
# 45   Nice place, room is small but clean, flat is i...    10008709
# 46   The host canceled this reservation 11 days bef...    10008709
# 70   The host canceled this reservation the day bef...    10015667
# 609  The host canceled this reservation 66 days bef...    10037904
#
#                                listing_url  \
# 44   https://www.airbnb.com/rooms/10008709
# 45   https://www.airbnb.com/rooms/10008709
# 46   https://www.airbnb.com/rooms/10008709
# 70   https://www.airbnb.com/rooms/10015667
# 609  https://www.airbnb.com/rooms/10037904
#
#                            listing_name   host_id  ... communication_rating  \
# 44          Cozy room in Friedrichshain  47456791  ...                   10
# 45          Cozy room in Friedrichshain  47456791  ...                   10
# 46          Cozy room in Friedrichshain  47456791  ...                   10
# 70   SchÃ¶ner Altbau in cooler Kiezlage  14847265  ...                    0
# 609     helle, ruhige Maisonettewohnung  10464825  ...                    8
#
#     location_rating value_rating instant_bookable business_travel_ready  \
# 44               10            6                f                     f
# 45               10            6                f                     f
# 46               10            6                f                     f
# 70                0            0                f                     f
# 609              10            9                f                     f
#
#     language                                   sentiment_scores neg_score  \
# 44        en  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0
# 45        en  {'neg': 0.0, 'neu': 0.558, 'pos': 0.442, 'comp...       0.0
# 46        en  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0
# 70        en  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0
# 609       en  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0
#
#     pos_score neu_score
# 44      0.000     1.000
# 45      0.442     0.558
# 46      0.000     1.000
# 70      0.000     1.000
# 609     0.000     1.000
#
# [5 rows x 52 columns]

# %%
least_rated_en['neg_score'].mean()
# Out:
# 0.022374306719979364

# %%
best_rated_en['neg_score'].mean()
# Out:
# 0.004994004360465116

# %%
sampled_df_en['neg_score'].mean()
# Out:
# 0.008908069760567544

# %%
least_rated_en['neg_score'].median()
# Out:
# 0.0

# %%
def show_score_dist(data_frame):
    sns.histplot(data=data_frame, x="pos_score", label="pos", color='green')
    sns.histplot(data=data_frame, x="neu_score", label="neu", color='gray')
    sns.histplot(data=data_frame, x="neg_score", label="neg", color='red')
    sns.set(style="darkgrid")
    plt.title("Distribution of score")
    plt.xlabel("Values")
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()

# %%
show_score_dist(least_rated_en)

# %%
# show_score_dist(sampled_df_en)

# %%
show_score_dist(best_rated_en)

# %% [markdown]
# We can observe through the graphs that the main difference between the least and the best rated dfs is in the distribution of the neutral score. Positive score is only partially more right distributed on positive properties reviews.

# %% [markdown]
# To double-check this observetion, I am going to print the correlation bìheatmap between the overall score and the positive, neutral and negative score

# %%
least_rated_en_sentiment = least_rated_en[['overall_rating', 'neg_score', 'neu_score', 'pos_score']]
best_rated_en_sentiment = best_rated_en[['overall_rating', 'neg_score', 'neu_score', 'pos_score']]

# %%
correlations_matrix = least_rated_en_sentiment.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

correlations_matrix
# Out:
#                 overall_rating  neg_score  neu_score  pos_score
# overall_rating        1.000000   0.064665  -0.397891   0.371230
# neg_score             0.064665   1.000000  -0.078141  -0.212962
# neu_score            -0.397891  -0.078141   1.000000  -0.957431
# pos_score             0.371230  -0.212962  -0.957431   1.000000

# %% [markdown]
# Neutral score has a negative correlation (-0.4) with the overall score. This confirms that a neutral tone in this context is to be perceived as negative. Let's see if the correlation with the best rated properties changes.

# %%
best_rated_en_sentiment
# Out:
#         overall_rating  neg_score  neu_score  pos_score
# 0                  100      0.000      0.462      0.538
# 19622              100      0.041      0.737      0.222
# 19776              100      0.000      0.633      0.367
# 19996              100      0.000      0.766      0.234
# 19997              100      0.000      0.661      0.339
# ...                ...        ...        ...        ...
# 435496             100      0.000      0.799      0.201
# 435497             100      0.000      0.799      0.201
# 435498             100      0.000      0.629      0.371
# 435499             100      0.000      0.680      0.320
# 435501             100      0.000      0.878      0.122
#
# [5504 rows x 4 columns]

# %%
correlations_matrix = best_rated_en_sentiment.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

correlations_matrix
# Out:
#                 overall_rating  neg_score  neu_score  pos_score
# overall_rating             NaN        NaN        NaN        NaN
# neg_score                  NaN   1.000000  -0.018135  -0.094431
# neu_score                  NaN  -0.018135   1.000000  -0.993655
# pos_score                  NaN  -0.094431  -0.993655   1.000000

# %% [markdown]
# Overall rating in this subdataset is always 100

# %% [markdown]
# I am going to analysise the most frequent non-grammatical words

# %%
grammatical_words = [
    'the', 'a', 'an', 'and', 'of', 'to', 'in', 'for', 'on', 'with', 'is', 'was', 'i',
    'as', 'by', 'at', 'about', 'from', 'into', 'over', 'after', 'through', 'before',
    'under', 'between', 'above', 'below', 'along', 'near', 'among', 'beside', 'behind',
    'beneath', 'next', 'among', 'upon', 'up', 'down', 'out', 'off', 'around', 'throughout',
    'underneath', 'within', 'without', 'during', 'except', 'until', 'since', 'unless',
    'where', 'when', 'while', 'who', 'which', 'whose', 'whom', 'that', 'these', 'those',
    'this', 'it', 'its', 'he', 'him', 'his', 'she', 'her', 'hers', 'they', 'them', 'their',
    'our', 'us', 'we', 'you', 'your', 'yours', 'I', 'me', 'my', 'mine', '-', 'U', 'were'
    ]

def get_most_frequent_words(data_frame, words_to_exclude):

    word_counter = Counter()

    for comment in data_frame['comments']:
        words = comment.split()
        for word in words:
            if word.lower() not in words_to_exclude:
                word_counter.update([word])

    word_frequency = pd.Series(word_counter).sort_values(ascending=False)
    return word_frequency

# %%
word_frequency_least_rated_en = get_most_frequent_words(least_rated_en, grammatical_words)

# %%
word_frequency_least_rated_en
# Out:
# very         3221
# apartment    1935
# host         1604
# place        1536
# but          1436
#              ...
# commu           1
# ledge           1
# lukew           1
# reflects        1
# chec            1
# Length: 14985, dtype: int64

# %%
word_frequency_best_rated_en = get_most_frequent_words(best_rated_en, grammatical_words)

# %%
word_frequency_best_rated_en
# Out:
# very                3182
# great               1578
# apartment           1500
# place               1496
# nice                1310
#                     ...
# well.Comfortable       1
# cleanness              1
# putting                1
# disturbed              1
# ot                     1
# Length: 12074, dtype: int64

# %%
word_frequency_sampled_en = get_most_frequent_words(sampled_df_en, grammatical_words)

# %%
word_frequency_sampled_en
# Out:
# very         3933
# apartment    2050
# great        2024
# place        1835
# nice         1470
#              ...
# chilly,         1
# cooker.         1
# Bike            1
# Dannielle       1
# Ema             1
# Length: 14877, dtype: int64

# %% [markdown]
# Comparing the frequency of words of least rated to the sample

# %%
word_frequency_sampled_en.sum()
# Out:
# 132877

# %%
word_frequency_best_rated_en.sum()
# Out:
# 105668

# %%
word_frequency_least_rated_en.sum()
# Out:
# 137301

# %% [markdown]
# To make possible a direct comparison, I am going to reduce proportionally the sum of the occurences of all non-grammatical words to about 100000

# %%
word_frequency_sampled_en_proportioned = word_frequency_sampled_en * 0.74738
word_frequency_sampled_en_proportioned.sum()
# Out:
# 99309.61226

# %%
word_frequency_best_rated_en_proportioned = word_frequency_best_rated_en * 0.94145
word_frequency_best_rated_en_proportioned.sum()
# Out:
# 99481.1386

# %%
word_frequency_least_rated_en_proportioned = word_frequency_least_rated_en * 0.72396
word_frequency_least_rated_en_proportioned.sum()
# Out:
# 99400.43196000002

# %% [markdown]
# Comparing the frequency of words of best rated to the sample

# %%
wordcloud1 = WordCloud(width=400, height=400, background_color='white')
wordcloud2 = WordCloud(width=400, height=400, background_color='white')

wordcloud1.generate_from_frequencies(word_frequency_best_rated_en_proportioned)
wordcloud2.generate_from_frequencies(word_frequency_least_rated_en_proportioned)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Display the word clouds side by side
axes[0].imshow(wordcloud1, interpolation='bilinear')
axes[0].set_title('Best Rated')
axes[0].axis('off')

axes[1].imshow(wordcloud2, interpolation='bilinear')
axes[1].set_title('Least Rated')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %%
sample_rated_words = word_frequency_sampled_en_proportioned[:20]
least_rated_words = word_frequency_least_rated_en_proportioned[:20]

plt.figure(figsize=(10, 6))  
sample_rated_words.plot(kind='bar', color='blue', alpha=0.7, label='Sample')
least_rated_words.plot(kind='bar', color='orange', alpha=0.7, label='Least Rated')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 Word Frequencies sampled vs least rated')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
sample_rated_words = word_frequency_sampled_en_proportioned[:30]
best_rated_words = word_frequency_best_rated_en_proportioned[:30]

plt.figure(figsize=(10, 6))  
sample_rated_words.plot(kind='bar', color='blue', alpha=0.7, label='Sample')
best_rated_words.plot(kind='bar', color='orange', alpha=0.7, label='Best Rated')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 Word Frequencies sample vs best rated')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
best_rated_words =  word_frequency_best_rated_en_proportioned[:20]
least_rated_words = word_frequency_least_rated_en_proportioned[:20]

plt.figure(figsize=(10, 6))  
best_rated_words.plot(kind='bar', color='blue', alpha=0.7, label='Best Rated')
least_rated_words.plot(kind='bar', color='orange', alpha=0.7, label='Least Rated')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 Word Frequencies best vs least rated')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# We can observe the strongest variation between the sample and the least rated reviews. Best reviews have a more significant difference in the intensifier very and more references to the appartment, the host and the place. While least rated more to the location, arrival, reservation. So, it seems they refer more to the experience itself.

# %% [markdown]
# Now, let's examine the frequencies on the other main languages.

# %% [markdown]
# GERMAN

# %%
german_best_rated = best_rated[best_rated['language'] == 'de']
german_least_rated = least_rated[least_rated['language'] == 'de']

# %%
german_best_rated.shape
# Out:
# (1774, 48)

# %%
common_grammatical_words_german = [
    'der', 'die', 'das', 'ein', 'eine', 'einen',
    'und', 'oder', 'aber', 
    'ist', 'sind', 'hat', 'habe', 'haben',
    'war', 'waren', 'bin', 'bist',
    'sich', 'mich', 'dich', 'ihn', 'sie', 'es', 'wir', 'ihr', 'Sie',
    'ich', 'du', 'er', 'sie', 'es', 'wir', 'ihr', 'sie', 'Sie',
    'mein', 'dein', 'sein', 'ihr', 'unser', 'euer', 'ihr', 'Ihr',
    'meine', 'deine', 'seine', 'ihre', 'unsere', 'eure', 'ihre', 'Ihre',
    'dieser', 'diese', 'dieses', 'jener', 'jene', 'jenes',
    'jeder', 'jede', 'jedes', 'alle', 'alles', 'viel', 'viele',
    'wenig', 'wenige', 'etwas', 'nichts', 'manche', 'manches',
    'manch', 'einige', 'ander', 'andere', 'anderes',
    'meinetwegen', 'nämlich', 'nicht', 'nichtsdestotrotz',
    'sowohl', 'zumindest', ' ',
    'zwecks', 'in', 'mit', 'fà¼r', 'zu', 'uns', 'man', 'auch', '-'
]

word_frequency_best_rated_de = get_most_frequent_words(german_best_rated, common_grammatical_words_german)
word_least_best_rated_de = get_most_frequent_words(german_least_rated, common_grammatical_words_german)

# %%
word_frequency_best_rated_de
# Out:
# sehr           1355
# Wohnung         832
# super           470
# Sehr            301
# Zimmer          277
#                ...
# Ruhe.Sehr         1
# uvm.Die           1
# Ort.Gerne         1
# wieder!L.G        1
# mitbenutzen       1
# Length: 6788, dtype: int64

# %%
word_least_best_rated_de
# Out:
# sehr                 1077
# Wohnung               837
# Lage                  322
# gut                   286
# super                 241
#                      ...
# WG-Zimmer,              1
# Service>>>              1
# Katya.                  1
# unberuecksichtig.       1
# anme                    1
# Length: 8040, dtype: int64

# %%
word_frequency_best_rated_de.sum()
# Out:
# 31258

# %%
word_least_best_rated_de.sum()
# Out:
# 32205

# %%
wordcloud1 = WordCloud(width=400, height=400, background_color='white')
wordcloud2 = WordCloud(width=400, height=400, background_color='white')

wordcloud1.generate_from_frequencies(word_frequency_best_rated_de)
wordcloud2.generate_from_frequencies(word_least_best_rated_de)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Display the word clouds side by side
axes[0].imshow(wordcloud1, interpolation='bilinear')
axes[0].set_title('Best Rated')
axes[0].axis('off')

axes[1].imshow(wordcloud2, interpolation='bilinear')
axes[1].set_title('Least Rated')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %%
word_frequency_best_rated_de_top_20 =  word_frequency_best_rated_de[:20]
word_frecuency_least_rated_de_top_20 = word_least_best_rated_de[:20]

plt.figure(figsize=(10, 6))  
word_frequency_best_rated_de_top_20.plot(kind='bar', color='blue', alpha=0.7, label='Best Rated')
word_frecuency_least_rated_de_top_20.plot(kind='bar', color='orange', alpha=0.7, label='Least Rated')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 German Word Frequencies best vs least rated')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# Also in German, we can observe less frequency of intensifier and positive adjectives. Less rated properties tend to have more neutral occurences

# %%
def filter_district(x):
    if x in ['Mitte', 'Friedrichshain-Kreuzberg', 'Pankow', 'Neukoeln', 'Charlottenburg - Wilmersdorf', 'Tempelhof - Schoeneberg']:
        return x
    else:
        return 'other'

# %%
district_df['neighborhood_group'] = district_df['neighborhood_group'].apply(filter_district)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 district_df['neighborhood_group'] = district_df['neighborhood_group'].apply(filter_district)
#
# NameError: name 'district_df' is not defined

# %%
sampled_df_en['neighborhood_group'] = sampled_df_en['neighborhood_group'].apply(filter_district)

# %%
sampled_df_en.to_csv('sampled_en_df.csv')
